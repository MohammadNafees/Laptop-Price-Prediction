# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptop_price.csv')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           CPU   RAM               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3       Intel Core i72 2.7GHz  16GB            512GB SSD
# 4       Intel Core i52 3.1GHz   8GB            256GB SSD
#
#                             GPU  OpSys  Weight    Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37  1339.69
# 1        Intel HD Graphics 6000  macOS    1.34   898.94
# 2         Intel HD Graphics 620  No OS    1.86   575.00
# 3            AMD Radeon Pro 455  macOS    1.83  2537.45
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1803.60

# %%
df.shape
# Out:
# (1275, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   TypeName          1275 non-null   object
#  2   Inches            1275 non-null   float64
#  3   ScreenResolution  1275 non-null   object
#  4   CPU               1275 non-null   object
#  5   RAM               1275 non-null   object
#  6   Memory            1275 non-null   object
#  7   GPU               1275 non-null   object
#  8   OpSys             1275 non-null   object
#  9   Weight            1275 non-null   float64
#  10  Price             1275 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 109.7+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# CPU                 0
# RAM                 0
# Memory              0
# GPU                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df['RAM'] = df['RAM'].str.replace('GB','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           CPU RAM               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3       Intel Core i72 2.7GHz  16            512GB SSD
# 4       Intel Core i52 3.1GHz   8            256GB SSD
#
#                             GPU  OpSys  Weight    Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37  1339.69
# 1        Intel HD Graphics 6000  macOS    1.34   898.94
# 2         Intel HD Graphics 620  No OS    1.86   575.00
# 3            AMD Radeon Pro 455  macOS    1.83  2537.45
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1803.60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   TypeName          1275 non-null   object
#  2   Inches            1275 non-null   float64
#  3   ScreenResolution  1275 non-null   object
#  4   CPU               1275 non-null   object
#  5   RAM               1275 non-null   object
#  6   Memory            1275 non-null   object
#  7   GPU               1275 non-null   object
#  8   OpSys             1275 non-null   object
#  9   Weight            1275 non-null   float64
#  10  Price             1275 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 109.7+ KB

# %%
df['RAM'] = df['RAM'].astype('int32')

# %%
import seaborn as sns

# %%
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.histplot(df['Inches'])
# Out:
# <Axes: xlabel='Inches', ylabel='Count'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                505
# 1366x768                                         263
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# 2560x1440                                          3
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches             ScreenResolution  \
# 761    Dell  Ultrabook    12.5            Full HD 1920x1080
# 745    Acer   Notebook    14.0                     1366x768
# 188    Acer  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 393     MSI     Gaming    17.3            Full HD 1920x1080
# 416    Dell   Notebook    13.3                     1366x768
#
#                                       CPU  RAM              Memory  \
# 761            Intel Core i7 7600U 2.8GHz   16           256GB SSD
# 745  Intel Celeron Dual Core N3060 1.6GHz    2  32GB Flash Storage
# 188             Intel Core i5 7Y54 1.2GHz    8           256GB SSD
# 393           Intel Core i7 7700HQ 2.8GHz    8           256GB SSD
# 416              Intel Core i3 6006U 2GHz    4           128GB SSD
#
#                             GPU       OpSys  Weight   Price  Touchscreen
# 761       Intel HD Graphics 620  Windows 10    1.18  1859.0            0
# 745       Intel HD Graphics 400   Chrome OS    1.68   330.0            0
# 188       Intel HD Graphics 615  Windows 10    1.12   989.0            0
# 393  Nvidia GeForce GTX 1050 Ti  Windows 10    2.70  1349.0            0
# 416       Intel HD Graphics 520  Windows 10    1.65   689.0            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           CPU  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3       Intel Core i72 2.7GHz   16            512GB SSD
# 4       Intel Core i52 3.1GHz    8            256GB SSD
#
#                             GPU  OpSys  Weight    Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37  1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   898.94            0    0
# 2         Intel HD Graphics 620  No OS    1.86   575.00            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1803.60            0    1

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches                     ScreenResolution  \
# 639     Dell            Notebook    15.6  4K Ultra HD / Touchscreen 3840x2160
# 1101    Dell           Ultrabook    12.5                             1366x768
# 824   Lenovo           Ultrabook    14.0          IPS Panel Full HD 1920x1080
# 374     Dell  2 in 1 Convertible    13.3      Full HD / Touchscreen 1920x1080
# 1180  Lenovo  2 in 1 Convertible    14.0      IPS Panel Touchscreen 2560x1440
#
#                               CPU  RAM               Memory  \
# 639   Intel Core i7 7700HQ 2.8GHz   16              1TB SSD
# 1101   Intel Core i3 6100U 2.3GHz    4            128GB SSD
# 824    Intel Core i5 7200U 2.5GHz    8  256GB Flash Storage
# 374    Intel Core i7 8550U 1.8GHz    8            256GB SSD
# 1180   Intel Core i5 6200U 2.3GHz    8            256GB SSD
#
#                           GPU       OpSys  Weight    Price  Touchscreen  Ips  \
# 639   Nvidia GeForce GTX 1050  Windows 10    2.06  2399.00            1    0
# 1101    Intel HD Graphics 520   Windows 7    1.50  1166.97            0    0
# 824     Intel HD Graphics 620  Windows 10    1.13  1875.00            0    1
# 374    Intel UHD Graphics 620  Windows 10    1.62   869.01            1    0
# 1180    Intel HD Graphics 520  Windows 10    1.36  1637.00            1    1
#
#                                X_res Y_res
# 639   4K Ultra HD / Touchscreen 3840  2160
# 1101                            1366   768
# 824           IPS Panel Full HD 1920  1080
# 374       Full HD / Touchscreen 1920  1080
# 1180      IPS Panel Touchscreen 2560  1440

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           CPU  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3       Intel Core i72 2.7GHz   16            512GB SSD
# 4       Intel Core i52 3.1GHz    8            256GB SSD
#
#                             GPU  OpSys  Weight    Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   898.94            0    0
# 2         Intel HD Graphics 620  No OS    1.86   575.00            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1803.60            0    1
#
#   X_res Y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   TypeName          1275 non-null   object
#  2   Inches            1275 non-null   float64
#  3   ScreenResolution  1275 non-null   object
#  4   CPU               1275 non-null   object
#  5   RAM               1275 non-null   int32
#  6   Memory            1275 non-null   object
#  7   GPU               1275 non-null   object
#  8   OpSys             1275 non-null   object
#  9   Weight            1275 non-null   float64
#  10  Price             1275 non-null   float64
#  11  Touchscreen       1275 non-null   int64
#  12  Ips               1275 non-null   int64
#  13  X_res             1275 non-null   int64
#  14  Y_res             1275 non-null   int64
# dtypes: float64(3), int32(1), int64(4), object(7)
# memory usage: 144.6+ KB

# %%
print(df.dtypes)
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# CPU                  object
# RAM                   int32
# Memory               object
# GPU                  object
# OpSys                object
# Weight              float64
# Price               float64
# Touchscreen           int64
# Ips                   int64
# X_res                 int64
# Y_res                 int64
# dtype: object

# %%
print(df['Price'].unique())
# Out:
# [1339.69  898.94  575.   2537.45 1803.6   400.   2139.97 1158.7  1495.
#   770.    393.9   344.99 2439.97  498.9  1262.4  1518.55  745.   2858.
#   499.    979.    191.9   999.    258.    819.    659.    418.64 1099.
#   800.   1298.    896.    244.99  199.    439.   1869.    998.    249.
\
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37  1339.69
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   898.94
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   575.00
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  2537.45
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37  1803.60
#
#    Touchscreen  Ips  X_res  Y_res         ppi
# 0            0    1   2560   1600  226.983005
# 1            0    0   1440    900  127.677940
# 2            0    0   1920   1080  141.211998
# 3            0    1   2880   1800  220.534624
# 4            0    1   2560   1600  226.983005

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         CPU  RAM               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook       Intel Core i72 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook       Intel Core i52 3.1GHz    8            256GB SSD
#
#                             GPU  OpSys  Weight    Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   898.94            0    0
# 2         Intel HD Graphics 620  No OS    1.86   575.00            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1803.60            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df['CPU'].value_counts()
# Out:
# CPU
# Intel Core i5 7200U 2.5GHz     191
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     132
# Intel Core i3 6006U 2GHz        80
# Intel Core i7 8550U 1.8GHz      73
#                               ...
# Intel Core M 6Y54 1.1GHz         1
# Samsung Cortex A72&A53 2GHz      1
# AMD E-Series 9000 2.2GHz         1
# Intel Core M 6Y30 0.9GHz         1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 114, dtype: int64

# %%
df['Cpu Name'] = df['CPU'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         CPU  RAM               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook       Intel Core i72 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook       Intel Core i52 3.1GHz    8            256GB SSD
#
#                             GPU  OpSys  Weight    Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   898.94            0    0
# 2         Intel HD Graphics 620  No OS    1.86   575.00            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1803.60            0    1
#
#           ppi        Cpu Name
# 0  226.983005   Intel Core i5
# 1  127.677940   Intel Core i5
# 2  141.211998   Intel Core i5
# 3  220.534624  Intel Core i72
# 4  226.983005  Intel Core i52

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         CPU  RAM               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook       Intel Core i72 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook       Intel Core i52 3.1GHz    8            256GB SSD
#
#                             GPU  OpSys  Weight    Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   898.94            0    0
# 2         Intel HD Graphics 620  No OS    1.86   575.00            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  1803.60            0    1
#
#           ppi        Cpu Name              Cpu brand
# 0  226.983005   Intel Core i5          Intel Core i5
# 1  127.677940   Intel Core i5          Intel Core i5
# 2  141.211998   Intel Core i5          Intel Core i5
# 3  220.534624  Intel Core i72  Other Intel Processor
# 4  226.983005  Intel Core i52  Other Intel Processor

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['CPU','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  RAM               Memory                           GPU  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight    Price  Touchscreen  Ips         ppi              Cpu brand
# 0  macOS    1.37  1339.69            0    1  226.983005          Intel Core i5
# 1  macOS    1.34   898.94            0    0  127.677940          Intel Core i5
# 2  No OS    1.86   575.00            0    0  141.211998          Intel Core i5
# 3  macOS    1.83  2537.45            0    1  220.534624  Other Intel Processor
# 4  macOS    1.37  1803.60            0    1  226.983005  Other Intel Processor

# %%
df['RAM'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RAM'>

# %%
sns.barplot(x=df['RAM'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        124
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 64GB SSD                           1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 512GB SSD +  256GB SSD             1
# 32GB HDD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# Clean up the Memory column
df["Memory"] = df["Memory"].astype(str).replace(r'\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

# Split the Memory information by '+'
new = df["Memory"].str.split("+", n=1, expand=True)
df["first"] = new[0].str.strip()  # Remove leading/trailing spaces
df["second"] = new[1].str.strip() if new.shape[1] > 1 else None

# Create features from the 'first' part
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Remove all non-digit characters from 'first'
df["first"] = df["first"].str.replace(r'\D', '', regex=True)

# Replace missing values in 'second' and process similarly
df["second"] = df["second"].fillna("0")
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)
df["second"] = df["second"].str.replace(r'\D', '', regex=True)

# Finally, convert these columns to integers
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

# %%
df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  RAM    Memory                       GPU  \
# 420   Lenovo  2 in 1 Convertible   16   512 SSD   Nvidia GeForce GTX 1050
# 541     Dell            Notebook    4   128 SSD     Intel HD Graphics 520
# 1155      HP            Notebook    4   256 SSD            AMD Radeon 520
# 194     Dell  2 in 1 Convertible    8  1000 HDD    Intel UHD Graphics 620
# 216   Lenovo            Notebook    8  1000 HDD  Nvidia GeForce GTX 940MX
#
#            OpSys  Weight    Price  Touchscreen  Ips         ppi  \
# 420   Windows 10    2.00  1899.00            1    1  282.423996
# 541   Windows 10    1.60   735.87            0    0  157.350512
# 1155  Windows 10    1.91   478.89            0    0  141.211998
# 194   Windows 10    1.62   839.00            1    1  165.632118
# 216        No OS    2.80   589.00            0    0  106.113062
#
#           Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# 420   Intel Core i7     0  512       0              0
# 541   Intel Core i3     0  128       0              0
# 1155  AMD Processor     0  256       0              0
# 194   Intel Core i7  1000    0       0              0
# 216   Intel Core i5  1000    0       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  RAM                           GPU  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#      Price  Touchscreen  Ips         ppi              Cpu brand  HDD  SSD  \
# 0  1339.69            0    1  226.983005          Intel Core i5    0  128
# 1   898.94            0    0  127.677940          Intel Core i5    0    0
# 2   575.00            0    0  141.211998          Intel Core i5    0  256
# 3  2537.45            0    1  220.534624  Other Intel Processor    0  512
# 4  1803.60            0    1  226.983005  Other Intel Processor    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# 1       0            128
# 2       0              0
# 3       0              0
# 4       0              0

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True) #Dropping this because hybrid and flash_storage shows negative relation with price

# %%
df.head()
# Out:
#   Company   TypeName  RAM                           GPU  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#      Price  Touchscreen  Ips         ppi              Cpu brand  HDD  SSD
# 0  1339.69            0    1  226.983005          Intel Core i5    0  128
# 1   898.94            0    0  127.677940          Intel Core i5    0    0
# 2   575.00            0    0  141.211998          Intel Core i5    0  256
# 3  2537.45            0    1  220.534624  Other Intel Processor    0  512
# 4  1803.60            0    1  226.983005  Other Intel Processor    0  256

# %%
df['GPU'].value_counts()
# Out:
# GPU
# Intel HD Graphics 620      280
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 106, dtype: int64

# %%
df['Gpu brand'] = df['GPU'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  RAM                           GPU  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#      Price  Touchscreen  Ips         ppi              Cpu brand  HDD  SSD  \
# 0  1339.69            0    1  226.983005          Intel Core i5    0  128
# 1   898.94            0    0  127.677940          Intel Core i5    0    0
# 2   575.00            0    0  141.211998          Intel Core i5    0  256
# 3  2537.45            0    1  220.534624  Other Intel Processor    0  512
# 4  1803.60            0    1  226.983005  Other Intel Processor    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     704
# Nvidia    396
# AMD       174
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     704
# Nvidia    396
# AMD       174
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['GPU'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  RAM  OpSys  Weight    Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37  1339.69            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   898.94            0    0
# 2      HP   Notebook    8  No OS    1.86   575.00            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  2537.45            0    1
# 4   Apple  Ultrabook    8  macOS    1.37  1803.60            0    1
#
#           ppi              Cpu brand  HDD  SSD Gpu brand
# 0  226.983005          Intel Core i5    0  128     Intel
# 1  127.677940          Intel Core i5    0    0     Intel
# 2  141.211998          Intel Core i5    0  256     Intel
# 3  220.534624  Other Intel Processor    0  512       AMD
# 4  226.983005  Other Intel Processor    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1048
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  RAM  OpSys  Weight    Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37  1339.69            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   898.94            0    0
# 2      HP   Notebook    8  No OS    1.86   575.00            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  2537.45            0    1
# 4   Apple  Ultrabook    8  macOS    1.37  1803.60            0    1
#
#           ppi              Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005          Intel Core i5    0  128     Intel                 Mac
# 1  127.677940          Intel Core i5    0    0     Intel                 Mac
# 2  141.211998          Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Other Intel Processor    0  512       AMD                 Mac
# 4  226.983005  Other Intel Processor    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\nfs66\AppData\Local\Temp\ipykernel_16280\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.histplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  RAM  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1270  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1271  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1272  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1273      HP            Notebook    6    2.19            0    0  100.454670
# 1274    Asus            Notebook    4    2.20            0    0  100.454670
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 0             Intel Core i5     0  128     Intel                 Mac
# 1             Intel Core i5     0    0     Intel                 Mac
# 2             Intel Core i5     0  256     Intel  Others/No OS/Linux
# 3     Other Intel Processor     0  512       AMD                 Mac
# 4     Other Intel Processor     0  256     Intel                 Mac
# ...                     ...   ...  ...       ...                 ...
# 1270          Intel Core i7     0  128     Intel             Windows
# 1271          Intel Core i7     0  512     Intel             Windows
# 1272  Other Intel Processor     0    0     Intel             Windows
# 1273          Intel Core i7  1000    0       AMD             Windows
# 1274  Other Intel Processor   500    0     Intel             Windows
#
# [1274 rows x 12 columns]

# %%
y
# Out:
# 0       7.200194
# 1       6.801216
# 2       6.354370
# 3       7.838915
# 4       7.497540
#           ...
# 1270    6.458338
# 1271    7.312553
# 1272    5.433722
# 1273    6.638568
# 1274    5.910797
# Name: Price, Length: 1274, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#      Company            TypeName  RAM  Weight  Touchscreen  Ips         ppi  \
# 21    Lenovo              Gaming    8    2.50            0    1  141.211998
# 790     Asus              Gaming    8    2.24            0    0  141.211998
# 273   Lenovo  2 in 1 Convertible   16    1.36            1    0  209.800683
# 397   Lenovo            Notebook    8    1.90            0    1  157.350512
# 921       HP           Ultrabook    8    1.84            0    0  141.211998
# ...      ...                 ...  ...     ...          ...  ...         ...
# 466     Acer            Notebook    4    2.20            0    0  100.454670
# 299     Asus           Ultrabook   16    1.63            0    0  141.211998
# 493     Acer            Notebook    8    2.20            0    0  100.454670
# 527   Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193   Apple           Ultrabook    8    0.92            0    1  226.415547
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 21            Intel Core i5  1000  128    Nvidia             Windows
# 790           Intel Core i7  1000  128    Nvidia             Windows
# 273           Intel Core i7     0  512     Intel             Windows
# 397           Intel Core i5     0  256     Intel             Windows
# 921           Intel Core i7     0  256       AMD             Windows
# ...                     ...   ...  ...       ...                 ...
# 466           Intel Core i3   500    0    Nvidia             Windows
# 299           Intel Core i7     0  512    Nvidia             Windows
# 493           AMD Processor  1000    0       AMD             Windows
# 527           Intel Core i3  2000    0    Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0    0     Intel                 Mac
#
# [1082 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8007186743057682
# MAE 0.20824090461972622

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7968687744599348
# MAE 0.21241293119591984

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7940836263470725
# MAE 0.2120857371094583

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7870370941929621
# MAE 0.19584215479956005

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8056346294108938
# MAE 0.2101531143180224

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.809753936864266
# MAE 0.19999817170955392

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.879200248853635
# MAE 0.16249100437215228

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7828796680028507
# MAE 0.22774268172143727

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8664526274111484
# MAE 0.1681152187965654

# %%
import sklearn
import xgboost

print("scikit-learn version:", sklearn.__version__)
print("XGBoost version:", xgboost.__version__)
# Out:
# scikit-learn version: 1.7.0
# XGBoost version: 3.0.2

# %%
# !pip install -U scikit-learn==1.3.2
# Out:
# Collecting scikit-learn==1.3.2
#   Using cached scikit_learn-1.3.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting numpy<2.0,>=1.17.3 (from scikit-learn==1.3.2)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\nfs66\downloads\data science\machine learning\laptop prediction\laptop_env\lib\site-packages (from scikit-learn==1.3.2) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\nfs66\downloads\data science\machine learning\laptop prediction\laptop_env\lib\site-packages (from scikit-learn==1.3.2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nfs66\downloads\data science\machine learning\laptop prediction\laptop_env\lib\site-packages (from scikit-learn==1.3.2) (3.6.0)
# Using cached scikit_learn-1.3.2-cp312-cp312-win_amd64.whl (9.1 MB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Installing collected packages: numpy, scikit-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.1
#     Uninstalling numpy-2.3.1:
#       Successfully uninstalled numpy-2.3.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.0
#     Uninstalling scikit-learn-1.7.0:
#       Successfully uninstalled scikit-learn-1.7.0
# Successfully installed numpy-1.26.4 scikit-learn-1.3.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\nfs66\Downloads\Data Science\Machine Learning\Laptop Prediction\laptop_env\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\nfs66\Downloads\Data Science\Machine Learning\Laptop Prediction\laptop_env\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\nfs66\Downloads\Data Science\Machine Learning\Laptop Prediction\laptop_env\Lib\site-packages\~klearn'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8578633477955334
# MAE 0.1718894816209363

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10,bootstrap=True)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8803821129267102
# MAE 0.16356917032436616

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8711160623417052
# MAE 0.16876609455654004

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  RAM  Weight    Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  1339.69            0    1
# 1      Apple           Ultrabook    8    1.34   898.94            0    0
# 2         HP            Notebook    8    1.86   575.00            0    0
# 3      Apple           Ultrabook   16    1.83  2537.45            0    1
# 4      Apple           Ultrabook    8    1.37  1803.60            0    1
# ...      ...                 ...  ...     ...      ...          ...  ...
# 1270  Lenovo  2 in 1 Convertible    4    1.80   638.00            1    1
# 1271  Lenovo  2 in 1 Convertible   16    1.30  1499.00            1    1
# 1272  Lenovo            Notebook    2    1.50   229.00            0    0
# 1273      HP            Notebook    6    2.19   764.00            0    0
# 1274    Asus            Notebook    4    2.20   369.00            0    0
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# 1     127.677940          Intel Core i5     0    0     Intel
# 2     141.211998          Intel Core i5     0  256     Intel
# 3     220.534624  Other Intel Processor     0  512       AMD
# 4     226.983005  Other Intel Processor     0  256     Intel
# ...          ...                    ...   ...  ...       ...
# 1270  157.350512          Intel Core i7     0  128     Intel
# 1271  276.053530          Intel Core i7     0  512     Intel
# 1272  111.935204  Other Intel Processor     0    0     Intel
# 1273  100.454670          Intel Core i7  1000    0       AMD
# 1274  100.454670  Other Intel Processor   500    0     Intel
#
#                       os
# 0                    Mac
# 1                    Mac
# 2     Others/No OS/Linux
# 3                    Mac
# 4                    Mac
# ...                  ...
# 1270             Windows
# 1271             Windows
# 1272             Windows
# 1273             Windows
# 1274             Windows
#
# [1274 rows x 13 columns]

# %%
X_train
# Out:
#      Company            TypeName  RAM  Weight  Touchscreen  Ips         ppi  \
# 21    Lenovo              Gaming    8    2.50            0    1  141.211998
# 790     Asus              Gaming    8    2.24            0    0  141.211998
# 273   Lenovo  2 in 1 Convertible   16    1.36            1    0  209.800683
# 397   Lenovo            Notebook    8    1.90            0    1  157.350512
# 921       HP           Ultrabook    8    1.84            0    0  141.211998
# ...      ...                 ...  ...     ...          ...  ...         ...
# 466     Acer            Notebook    4    2.20            0    0  100.454670
# 299     Asus           Ultrabook   16    1.63            0    0  141.211998
# 493     Acer            Notebook    8    2.20            0    0  100.454670
# 527   Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193   Apple           Ultrabook    8    0.92            0    1  226.415547
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 21            Intel Core i5  1000  128    Nvidia             Windows
# 790           Intel Core i7  1000  128    Nvidia             Windows
# 273           Intel Core i7     0  512     Intel             Windows
# 397           Intel Core i5     0  256     Intel             Windows
# 921           Intel Core i7     0  256       AMD             Windows
# ...                     ...   ...  ...       ...                 ...
# 466           Intel Core i3   500    0    Nvidia             Windows
# 299           Intel Core i7     0  512    Nvidia             Windows
# 493           AMD Processor  1000    0       AMD             Windows
# 527           Intel Core i3  2000    0    Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0    0     Intel                 Mac
#
# [1082 rows x 12 columns]
